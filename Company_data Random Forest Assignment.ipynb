# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
from sklearn import preprocessing

# %%
# import some data to play with
Company_data = pd.read_csv('Company_Data.csv')

# %%
Company_data.isnull().any()
# Out:
# Sales          False
# CompPrice      False
# Income         False
# Advertising    False
# Population     False
# Price          False
# ShelveLoc      False
# Age            False
# Education      False
# Urban          False
# US             False
# dtype: bool

# %%
Company_data.tail(5)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes

# %%
#using label Encoder function in categorical Column
lablel_encoder=preprocessing.LabelEncoder()
Company_data['ShelveLoc']=lablel_encoder.fit_transform(Company_data['ShelveLoc'])
Company_data['Urban']=lablel_encoder.fit_transform(Company_data['Urban'])
Company_data['US']=lablel_encoder.fit_transform(Company_data['US'])

# %%
Company_data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120          0   42
# 1    11.22        111      48           16         260     83          1   65
# 2    10.06        113      35           10         269     80          2   59
# 3     7.40        117     100            4         466     97          2   55
# 4     4.15        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128          1   33
# 396   6.14        139      23            3          37    120          2   55
# 397   7.41        162      26           12         368    159          2   40
# 398   5.94        100      79            7         284     95          0   50
# 399   9.71        134      37            0          27    120          1   49
#
#      Education  Urban  US
# ...

# %%
Company_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    int32
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    int32
#  10  US           400 non-null    int32
# dtypes: float64(1), int32(3), int64(7)
# memory usage: 29.8 KB

# %%
Company_data["Sales"].min()
# Out:
# 0.0

# %%
Company_data["Sales"].max()
# Out:
# 16.27

# %%
Company_data.Sales.value_counts()
# Out:
# 7.80    4
# 8.77    3
# 9.32    3
# 4.10    3
# 6.20    3
#        ..
# 3.67    1
# 7.62    1
# 9.54    1
# 8.41    1
# 9.71    1
# Name: Sales, Length: 336, dtype: int64

# %%
Company_data["Sales"].median()
# Out:
# 7.49

# %%
Company_data.loc[Company_data["Sales"]>=7.5,"sale"]="High"

# %%
Company_data.loc[Company_data["Sales"]<=7.5,"sale"]="Low"

# %%
Company_data.sale.value_counts()
# Out:
# Low     202
# High    198
# Name: sale, dtype: int64

# %%
Company_data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120          0   42
# 1    11.22        111      48           16         260     83          1   65
# 2    10.06        113      35           10         269     80          2   59
# 3     7.40        117     100            4         466     97          2   55
# 4     4.15        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128          1   33
# 396   6.14        139      23            3          37    120          2   55
# 397   7.41        162      26           12         368    159          2   40
# 398   5.94        100      79            7         284     95          0   50
# 399   9.71        134      37            0          27    120          1   49
#
#      Education  Urban  US  sale
# ...

# %%
Company_data['sale']=lablel_encoder.fit_transform(Company_data['sale'])

# %%
Company_data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120          0   42
# 1    11.22        111      48           16         260     83          1   65
# 2    10.06        113      35           10         269     80          2   59
# 3     7.40        117     100            4         466     97          2   55
# 4     4.15        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128          1   33
# 396   6.14        139      23            3          37    120          2   55
# 397   7.41        162      26           12         368    159          2   40
# 398   5.94        100      79            7         284     95          0   50
# 399   9.71        134      37            0          27    120          1   49
#
#      Education  Urban  US  sale
# ...

# %%
Company_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    int32
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    int32
#  10  US           400 non-null    int32
#  11  sale         400 non-null    int32
# dtypes: float64(1), int32(4), int64(7)
# memory usage: 31.4 KB

# %%
import seaborn as sns 
sns.pairplot(data=Company_data, hue="sale")

# %%
X=Company_data.iloc[:,1:11]
y=Company_data.iloc[:,11]

# %%
X
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120          0   42
# 1          111      48           16         260     83          1   65
# 2          113      35           10         269     80          2   59
# 3          117     100            4         466     97          2   55
# 4          141      64            3         340    128          0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128          1   33
# 396        139      23            3          37    120          2   55
# 397        162      26           12         368    159          2   40
# 398        100      79            7         284     95          0   50
# 399        134      37            0          27    120          1   49
#
#      Education  Urban  US
# 0           17      1   1
# 1           10      1   1
# 2           12      1   1
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 395    0
# 396    1
# 397    1
# 398    1
# 399    0
# Name: sale, Length: 400, dtype: int32

# %%
colnames = list(Company_data.columns)
colnames
# Out:
# ['Sales',
#  'CompPrice',
#  'Income',
#  'Advertising',
#  'Population',
#  'Price',
#  'ShelveLoc',
#  'Age',
#  'Education',
#  'Urban',
#  'US',
#  'sale']

# %%
# Splitting data into training and testing data set
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y, test_size=0.20,random_state=42) 
X_train.shape, X_test.shape
# Out:
# ((320, 10), (80, 10))

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier_rf = RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=5,
                                       n_estimators=100, oob_score=True)

# %%
classifier_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_jobs=-1, oob_score=True, random_state=42)

# %%
# checking the oob score
classifier_rf.oob_score_
# Out:
# 0.796875

# %%
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf': [5,10,20,50,100,200],
    'n_estimators': [10,25,30,50,100,200]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 4,
                           n_jobs=-1, verbose=1, scoring="accuracy")

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 180 candidates, totalling 720 fits
# GridSearchCV(cv=4, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100, 200],
#                          'n_estimators': [10, 25, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_score_
# Out:
# 0.78125

# %%
rf_best = grid_search.best_estimator_
rf_best
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=10, n_estimators=200,
#                        n_jobs=-1, random_state=42)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(80,40))
plot_tree(rf_best.estimators_[5], feature_names = X.columns,class_names=['High', "Low"],filled=True)
# Out:
# [Text(0.44642857142857145, 0.9375, 'ShelveLoc <= 0.5\ngini = 0.49\nsamples = 197\nvalue = [137, 183]\nclass = Low'),
#  Text(0.21428571428571427, 0.8125, 'Income <= 99.0\ngini = 0.278\nsamples = 51\nvalue = [15, 75]\nclass = Low'),
#  Text(0.14285714285714285, 0.6875, 'Population <= 285.0\ngini = 0.153\nsamples = 41\nvalue = [6, 66]\nclass = Low'),
#  Text(0.07142857142857142, 0.5625, 'gini = 0.0\nsamples = 23\nvalue = [0, 43]\nclass = Low'),
#  Text(0.21428571428571427, 0.5625, 'gini = 0.328\nsamples = 18\nvalue = [6, 23]\nclass = Low'),
#  Text(0.2857142857142857, 0.6875, 'gini = 0.5\nsamples = 10\nvalue = [9, 9]\nclass = High'),
#  Text(0.6785714285714286, 0.8125, 'Age <= 73.5\ngini = 0.498\nsamples = 146\nvalue = [122, 108]\nclass = High'),
#  Text(0.5, 0.6875, 'Population <= 228.5\ngini = 0.479\nsamples = 125\nvalue = [117, 77]\nclass = High'),
#  Text(0.35714285714285715, 0.5625, 'Income <= 35.5\ngini = 0.5\nsamples = 53\nvalue = [42, 42]\nclass = High'),
# ...

# %%
rf_best.feature_importances_
# Out:
# array([0.0768162 , 0.06203326, 0.14844194, 0.05775147, 0.30928552,
#        0.15700582, 0.15531455, 0.02111139, 0.00505733, 0.00718252])

# %%
imp_df = pd.DataFrame({
    "Varname": X_train.columns,
    "Imp": rf_best.feature_importances_
})

# %%
imp_df.sort_values(by="Imp", ascending=False)
# Out:
#        Varname       Imp
# 4        Price  0.309286
# 5    ShelveLoc  0.157006
# 6          Age  0.155315
# 2  Advertising  0.148442
# 0    CompPrice  0.076816
# 1       Income  0.062033
# 3   Population  0.057751
# 7    Education  0.021111
# 9           US  0.007183
# 8        Urban  0.005057

# %%
# Random Forest Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

array=Company_data.values
X=array[:,0:9]
y=array[:,9]
num_trees = 500
max_features = 3 #Total features=9
kfold = KFold(n_splits=10, random_state=7,shuffle=True)
model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features)
results = cross_val_score(model, X, y, cv=kfold)
print(results.mean())
# Out:
# 0.68

# %%
# AdaBoost Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier
filename = 'Company_Data.csv'
names = ['Sales',
 'CompPrice',
 'Income',
 'Advertising',
 'Population',
 'Price',
 'ShelveLoc',
 'Age',
 'Education',
 'Urban',
 'US',
 'sale']
dataframe = read_csv(filename, names=names)

array=Company_data.values
X=array[:,0:9]
y=array[:,9]

num_trees = 10
seed=7
kfold = KFold(n_splits=10, random_state=seed,shuffle=True)
model = AdaBoostClassifier(n_estimators=num_trees, random_state=seed)
results = cross_val_score(model, X, y, cv=kfold)
print(results.mean())
# Out:
# 0.6549999999999999

# %%
# Stacking Ensemble for Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
filename = 'Company_Data.csv'
names = ['Sales',
 'CompPrice',
 'Income',
 'Advertising',
 'Population',
 'Price',
 'ShelveLoc',
 'Age',
 'Education',
 'Urban',
 'US',
 'sale']
dataframe = read_csv(filename, names=names)

array=Company_data.values
X=array[:,0:9]
y=array[:,9]
kfold = KFold(n_splits=10, random_state=7,shuffle=True)

# create the sub models
estimators = []
model1 = LogisticRegression(max_iter=500)
estimators.append(('logistic', model1))
model2 = DecisionTreeClassifier()
estimators.append(('cart', model2))
model3 = SVC()
estimators.append(('svm', model3))

# create the ensemble model
ensemble = VotingClassifier(estimators)
results = cross_val_score(ensemble, X, y, cv=kfold)
print(results.mean())
# Out:
# 0.7049999999999998
